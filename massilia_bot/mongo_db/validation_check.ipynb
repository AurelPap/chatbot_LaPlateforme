# %%
from mongo_operations import MongoOperations

with MongoOperations() as mongo_ops:
    print('-----------------delete')
    mongo_ops.delete_data()
    print('-----------------reset')
    mongo_ops.reset_data()

    print('-----------------add')
    q_and_a_list = [
            {
                'tag': 'poissson davril',
                'patterns': ["Quels sont les avantages spécifiques de suivre la formation de Développeur Logiciel à l'école La Plateforme par rapport à d'autres programmes similaires ?"],
                'responses': ['L\'école offre des places limitées avec des frais de scolarité à 0€, une première année intensive suivie d\'une alternance enrichissante, et un réseau d\'entreprises partenaires facilitant l\'insertion professionnelle des diplômés.']
            },
            {
                'tag': 'poissson demai',
                'patterns': ["Quelles sont les compétences non techniques importantes enseignées dans le cadre de la formation de Développeur Logiciel à La Plateforme ?"],
                'responses': ['En plus des compétences techniques, l\'école met l\'accent sur la gestion de projet, le développement de micro services, la sécurité du développement, le déploiement continu, la supervision de la qualité, et les tests unitaires.']
            },
            {
                'tag': 'centralediglab',
                'patterns': ["Quels sont les objectifs de la formation MSc IT Business IA et Data ?"],
                'responses': ['La formation vise à développer une expertise en intelligence artificielle et en analyse de données, et à préparer les étudiants à des carrières en stratégie numérique et en gestion de projets IT.']
            }
        ]
    mongo_ops.add_data(q_and_a_list)

    print('-----------------fetch')
    mongo_ops.fetch_data()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# -----------------delete
# Collection 'chatbot' supprimée.
# Nombre de documents dans la collection après la suppression : 0
# -----------------reset
# Opened json file with 19 intents.
# La db a été réinitialisée avec les données du fichier
# -----------------add
# Nombre de documents dans la collection avant l'insertion : 19
# Les données ont bien été récupérés
# Collection 'chatbot' supprimée.
# Nombre de documents dans la collection après la suppression : 0
# Nombre de documents dans la collection après l'insertion : 21
# -----------------fetch
# Les données ont bien été récupérés

# %%
from mongo_operations import MongoOperations

mongops = MongoOperations()
print('-----------------delete')
mongo_ops.delete_data()
print('-----------------reset')
mongo_ops.reset_data()

print('-----------------add')
q_and_a_list = [
        {
            "tag":"AI",
            "patterns": ["What is AI?"],
            "answer": ["Artificial Intelligence is the simulation of human intelligence in machines."]
        },
        {
            "tag":"msc-it-business-ia-data",
            "patterns": ["What is ML?"],
            "answer": ["Machine Learning is a subset of AI that involves training algorithms on data."]
        }
    ]
mongo_ops.add_data(q_and_a_list)

print('-----------------fetch')
mongo_ops.fetch_data()
mongo_ops.reset_data()
# Out:
# -----------------delete
# Collection 'chatbot' supprimée.
# Nombre de documents dans la collection après la suppression : 0
# -----------------reset
# Opened json file with 19 intents.
# La db a été réinitialisée avec les données du fichier
# -----------------add
# Nombre de documents dans la collection avant l'insertion : 19
# Les données ont bien été récupérés
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 22
#       9 print('-----------------add')
#      10 q_and_a_list = [
#      11         {
#      12             "tag":"AI",
#    (...)
#      20         }
#      21     ]
# ---> 22 mongo_ops.add_data(q_and_a_list)
#      24 print('-----------------fetch')
#      25 mongo_ops.fetch_data()
#
# File ~/code/plateforme/main_aws/massilia_bot/mongo_db/mongo_operations.py:51, in MongoOperations.add_data(self, q_and_a_list)
#      49 if tag in existing_data:
# ...

# %%
# from mongo_db_functions import delete_data, add_data, fetch_data, reset_data

# # Example usage
# print('-----------------delete')
# delete_data()
# print('-----------------add')
# add_data("What is AI?", "Artificial Intelligence is the simulation of human intelligence in machines.")
# print('-----------------fetch')
# fetch_data()
# print('-----------------reset')
# reset_data()

# %%
mongo_ops.add_data(q_and_a_list)
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mongo_ops.add_data(q_and_a_list)
#
# File ~/code/plateforme/main_aws/massilia_bot/mongo_db/mongo_operations.py:33, in MongoOperations.add_data(self, q_and_a_list)
#      32 def add_data(self, q_and_a_list):
# ---> 33     count_documents_before = self.collection.count_documents({})
#      34     print(f"Nombre de documents dans la collection avant l'insertion : {count_documents_before}")
#      36     # Ensure that q_and_a_list is a list of dictionaries
#
# File ~/.pyenv/versions/lewagon/envs/massilia_mongo_db/lib/python3.8/site-packages/pymongo/collection.py:1899, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    1896         return 0
#    1897     return result["n"]
# -> 1899 return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#
# ...
